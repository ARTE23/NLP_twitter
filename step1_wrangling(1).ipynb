# %% [markdown]
# # NLP on Tweets about Crypto Markets
#
# ### by Artemij Kiel and Roman Pavlyutin

# %% [markdown]
# **Step 1. Data Wrangling**
#
# The text file that we are aiming to analyze is rather big, 4.41 GB. It contains about 8 million tweets that have been parsed in one day. Due to the sheer size of the file, we could not use pandas for this task, it would not be able to handle our data. Thus, we decided to use dask.

# %%
import json
from dask import bag as db 
from dask import dataframe as dd

# %% [markdown]
# Here, we added a Client to be able to track the progress.

# %%
from dask.distributed import Client
client=Client(n_workers=8,)
client
# Out:
# <Client: 'tcp://127.0.0.1:59789' processes=8 threads=8, memory=8.00 GiB>

# %% [markdown]
# Reading in the file:

# %%
#a will be the database as .txt

a=db.read_text("/Users/romanpavlyutin/Desktop/tweets0408.txt",blocksize="50MB")

# %% [markdown]
# Use a cleaner:

# %%
# takes away/ cuts of the first and the last sign of every line in the text-document
# json.dumps makes a json-string out of a python-object
# json.loads makes a python-object out of a json-string
# sort_key=True as argument in dumps, sorts the key alphabetically. The keys are the column names.

def cleaner(a):
    return a[0:-2]

# %%
# map uses the above defined function "cleaner" on every element 

b=a.map(cleaner).map(json.loads).to_dataframe()

b.set_index("tweet_id").to_parquet("parquet")
# Out:
# 2022-06-17 14:45:59,703 - distributed.worker_memory - WARNING - Worker is at 80% memory usage. Pausing worker.  Process memory: 824.92 MiB -- Worker memory limit: 1.00 GiB
# 2022-06-17 14:46:01,451 - distributed.worker_memory - WARNING - Worker is at 44% memory usage. Resuming worker. Process memory: 457.76 MiB -- Worker memory limit: 1.00 GiB
# 2022-06-17 14:50:31,584 - distributed.worker - ERROR - Worker stream died during communication: tcp://127.0.0.1:59829
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/distributed/comm/tcp.py", line 266, in write
#     async def write(self, msg, serializers=None, on_error="message"):
# asyncio.exceptions.CancelledError
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/asyncio/tasks.py", line 418, in wait_for
#     return fut.result()
# asyncio.exceptions.CancelledError
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/distributed/comm/core.py", line 327, in connect
#     await asyncio.wait_for(comm.write(local_info), time_left())
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/asyncio/tasks.py", line 420, in wait_for
#     raise exceptions.TimeoutError() from exc
# asyncio.exceptions.TimeoutError
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/distributed/worker.py", line 3296, in gather_dep
#     response = await get_data_from_worker(
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/distributed/worker.py", line 4680, in get_data_from_worker
#     return await retry_operation(_get_data, operation="get_data_from_worker")
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/distributed/utils_comm.py", line 381, in retry_operation
#     return await retry(
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/distributed/utils_comm.py", line 366, in retry
#     return await coro()
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/distributed/worker.py", line 4657, in _get_data
#     comm = await rpc.connect(worker)
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/distributed/core.py", line 1202, in connect
#     return await connect_attempt
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/distributed/core.py", line 1138, in _connect
#     comm = await connect(
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/distributed/comm/core.py", line 331, in connect
#     raise OSError(
# OSError: Timed out during handshake while connecting to tcp://127.0.0.1:59829 after 30 s
# 2022-06-17 14:52:03,920 - distributed.worker - ERROR - Worker stream died during communication: tcp://127.0.0.1:59817
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/distributed/comm/tcp.py", line 439, in connect
#     stream = await self.client.connect(
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/tornado/tcpclient.py", line 275, in connect
#     af, addr, stream = await connector.start(connect_timeout=timeout)
# asyncio.exceptions.CancelledError
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/asyncio/tasks.py", line 456, in wait_for
#     return fut.result()
# asyncio.exceptions.CancelledError
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/distributed/comm/core.py", line 289, in connect
#     comm = await asyncio.wait_for(
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/asyncio/tasks.py", line 458, in wait_for
#     raise exceptions.TimeoutError() from exc
# asyncio.exceptions.TimeoutError
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/distributed/worker.py", line 3296, in gather_dep
#     response = await get_data_from_worker(
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/distributed/worker.py", line 4680, in get_data_from_worker
#     return await retry_operation(_get_data, operation="get_data_from_worker")
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/distributed/utils_comm.py", line 381, in retry_operation
#     return await retry(
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/distributed/utils_comm.py", line 366, in retry
#     return await coro()
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/distributed/worker.py", line 4657, in _get_data
#     comm = await rpc.connect(worker)
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/distributed/core.py", line 1202, in connect
#     return await connect_attempt
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/distributed/core.py", line 1138, in _connect
#     comm = await connect(
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/distributed/comm/core.py", line 315, in connect
#     raise OSError(
# OSError: Timed out trying to connect to tcp://127.0.0.1:59817 after 30 s
# 2022-06-17 14:53:13,558 - distributed.worker - ERROR - Worker stream died during communication: tcp://127.0.0.1:59817
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/distributed/comm/tcp.py", line 226, in read
#     frames_nbytes = await stream.read_bytes(fmt_size)
# asyncio.exceptions.CancelledError
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/asyncio/tasks.py", line 456, in wait_for
#     return fut.result()
# asyncio.exceptions.CancelledError
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/distributed/comm/core.py", line 326, in connect
#     handshake = await asyncio.wait_for(comm.read(), time_left())
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/asyncio/tasks.py", line 458, in wait_for
#     raise exceptions.TimeoutError() from exc
# asyncio.exceptions.TimeoutError
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/distributed/worker.py", line 3296, in gather_dep
#     response = await get_data_from_worker(
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/distributed/worker.py", line 4680, in get_data_from_worker
#     return await retry_operation(_get_data, operation="get_data_from_worker")
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/distributed/utils_comm.py", line 381, in retry_operation
#     return await retry(
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/distributed/utils_comm.py", line 366, in retry
#     return await coro()
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/distributed/worker.py", line 4657, in _get_data
#     comm = await rpc.connect(worker)
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/distributed/core.py", line 1202, in connect
#     return await connect_attempt
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/distributed/core.py", line 1138, in _connect
#     comm = await connect(
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/distributed/comm/core.py", line 331, in connect
#     raise OSError(
# OSError: Timed out during handshake while connecting to tcp://127.0.0.1:59817 after 30 s
# 2022-06-17 14:53:46,647 - distributed.worker - ERROR - Worker stream died during communication: tcp://127.0.0.1:59820
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/distributed/comm/tcp.py", line 439, in connect
#     stream = await self.client.connect(
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/tornado/tcpclient.py", line 275, in connect
#     af, addr, stream = await connector.start(connect_timeout=timeout)
# asyncio.exceptions.CancelledError
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/asyncio/tasks.py", line 456, in wait_for
#     return fut.result()
# asyncio.exceptions.CancelledError
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/distributed/comm/core.py", line 289, in connect
#     comm = await asyncio.wait_for(
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/asyncio/tasks.py", line 458, in wait_for
#     raise exceptions.TimeoutError() from exc
# asyncio.exceptions.TimeoutError
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/distributed/worker.py", line 3296, in gather_dep
#     response = await get_data_from_worker(
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/distributed/worker.py", line 4680, in get_data_from_worker
#     return await retry_operation(_get_data, operation="get_data_from_worker")
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/distributed/utils_comm.py", line 381, in retry_operation
#     return await retry(
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/distributed/utils_comm.py", line 366, in retry
#     return await coro()
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/distributed/worker.py", line 4657, in _get_data
#     comm = await rpc.connect(worker)
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/distributed/core.py", line 1202, in connect
#     return await connect_attempt
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/distributed/core.py", line 1138, in _connect
#     comm = await connect(
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/distributed/comm/core.py", line 315, in connect
#     raise OSError(
# OSError: Timed out trying to connect to tcp://127.0.0.1:59820 after 30 s
# 2022-06-17 15:00:21,246 - distributed.worker - ERROR - Worker stream died during communication: tcp://127.0.0.1:59817
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/distributed/comm/tcp.py", line 439, in connect
#     stream = await self.client.connect(
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/tornado/tcpclient.py", line 265, in connect
#     addrinfo = await self.resolver.resolve(host, port, af)
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/distributed/comm/tcp.py", line 424, in resolve
#     for fam, _, _, _, address in await asyncio.get_running_loop().getaddrinfo(
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/asyncio/base_events.py", line 855, in getaddrinfo
#     return await self.run_in_executor(
# asyncio.exceptions.CancelledError
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/asyncio/tasks.py", line 456, in wait_for
#     return fut.result()
# asyncio.exceptions.CancelledError
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/distributed/comm/core.py", line 289, in connect
#     comm = await asyncio.wait_for(
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/asyncio/tasks.py", line 458, in wait_for
#     raise exceptions.TimeoutError() from exc
# asyncio.exceptions.TimeoutError
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/distributed/worker.py", line 3296, in gather_dep
#     response = await get_data_from_worker(
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/distributed/worker.py", line 4680, in get_data_from_worker
#     return await retry_operation(_get_data, operation="get_data_from_worker")
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/distributed/utils_comm.py", line 381, in retry_operation
#     return await retry(
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/distributed/utils_comm.py", line 366, in retry
#     return await coro()
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/distributed/worker.py", line 4657, in _get_data
#     comm = await rpc.connect(worker)
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/distributed/core.py", line 1202, in connect
#     return await connect_attempt
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/distributed/core.py", line 1138, in _connect
#     comm = await connect(
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/distributed/comm/core.py", line 315, in connect
#     raise OSError(
# OSError: Timed out trying to connect to tcp://127.0.0.1:59817 after 30 s
# 2022-06-17 15:01:17,145 - distributed.worker - ERROR - Worker stream died during communication: tcp://127.0.0.1:59817
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/distributed/comm/tcp.py", line 226, in read
#     frames_nbytes = await stream.read_bytes(fmt_size)
# asyncio.exceptions.CancelledError
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/asyncio/tasks.py", line 456, in wait_for
#     return fut.result()
# asyncio.exceptions.CancelledError
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/distributed/comm/core.py", line 326, in connect
#     handshake = await asyncio.wait_for(comm.read(), time_left())
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/asyncio/tasks.py", line 458, in wait_for
#     raise exceptions.TimeoutError() from exc
# asyncio.exceptions.TimeoutError
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/distributed/worker.py", line 3296, in gather_dep
#     response = await get_data_from_worker(
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/distributed/worker.py", line 4680, in get_data_from_worker
#     return await retry_operation(_get_data, operation="get_data_from_worker")
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/distributed/utils_comm.py", line 381, in retry_operation
#     return await retry(
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/distributed/utils_comm.py", line 366, in retry
#     return await coro()
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/distributed/worker.py", line 4657, in _get_data
#     comm = await rpc.connect(worker)
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/distributed/core.py", line 1202, in connect
#     return await connect_attempt
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/distributed/core.py", line 1138, in _connect
#     comm = await connect(
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/distributed/comm/core.py", line 331, in connect
#     raise OSError(
# OSError: Timed out during handshake while connecting to tcp://127.0.0.1:59817 after 30 s
# 2022-06-17 15:01:47,543 - distributed.worker - ERROR - Worker stream died during communication: tcp://127.0.0.1:59817
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/distributed/comm/tcp.py", line 226, in read
#     frames_nbytes = await stream.read_bytes(fmt_size)
# asyncio.exceptions.CancelledError
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/asyncio/tasks.py", line 456, in wait_for
#     return fut.result()
# asyncio.exceptions.CancelledError
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/distributed/comm/core.py", line 326, in connect
#     handshake = await asyncio.wait_for(comm.read(), time_left())
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/asyncio/tasks.py", line 458, in wait_for
#     raise exceptions.TimeoutError() from exc
# asyncio.exceptions.TimeoutError
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/distributed/worker.py", line 3296, in gather_dep
#     response = await get_data_from_worker(
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/distributed/worker.py", line 4680, in get_data_from_worker
#     return await retry_operation(_get_data, operation="get_data_from_worker")
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/distributed/utils_comm.py", line 381, in retry_operation
#     return await retry(
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/distributed/utils_comm.py", line 366, in retry
#     return await coro()
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/distributed/worker.py", line 4657, in _get_data
#     comm = await rpc.connect(worker)
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/distributed/core.py", line 1202, in connect
#     return await connect_attempt
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/distributed/core.py", line 1138, in _connect
#     comm = await connect(
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/distributed/comm/core.py", line 331, in connect
#     raise OSError(
# OSError: Timed out during handshake while connecting to tcp://127.0.0.1:59817 after 30 s
# 2022-06-17 15:04:45,725 - distributed.worker - ERROR - Worker stream died during communication: tcp://127.0.0.1:59820
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/distributed/comm/tcp.py", line 226, in read
#     frames_nbytes = await stream.read_bytes(fmt_size)
# asyncio.exceptions.CancelledError
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/asyncio/tasks.py", line 456, in wait_for
#     return fut.result()
# asyncio.exceptions.CancelledError
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/distributed/comm/core.py", line 326, in connect
#     handshake = await asyncio.wait_for(comm.read(), time_left())
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/asyncio/tasks.py", line 458, in wait_for
#     raise exceptions.TimeoutError() from exc
# asyncio.exceptions.TimeoutError
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/distributed/worker.py", line 3296, in gather_dep
#     response = await get_data_from_worker(
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/distributed/worker.py", line 4680, in get_data_from_worker
#     return await retry_operation(_get_data, operation="get_data_from_worker")
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/distributed/utils_comm.py", line 381, in retry_operation
#     return await retry(
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/distributed/utils_comm.py", line 366, in retry
#     return await coro()
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/distributed/worker.py", line 4657, in _get_data
#     comm = await rpc.connect(worker)
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/distributed/core.py", line 1202, in connect
#     return await connect_attempt
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/distributed/core.py", line 1138, in _connect
#     comm = await connect(
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/distributed/comm/core.py", line 331, in connect
#     raise OSError(
# OSError: Timed out during handshake while connecting to tcp://127.0.0.1:59820 after 30 s
# 2022-06-17 15:05:32,816 - distributed.worker - ERROR - Worker stream died during communication: tcp://127.0.0.1:59820
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/distributed/comm/tcp.py", line 226, in read
#     frames_nbytes = await stream.read_bytes(fmt_size)
# asyncio.exceptions.CancelledError
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/asyncio/tasks.py", line 456, in wait_for
#     return fut.result()
# asyncio.exceptions.CancelledError
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/distributed/comm/core.py", line 326, in connect
#     handshake = await asyncio.wait_for(comm.read(), time_left())
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/asyncio/tasks.py", line 458, in wait_for
#     raise exceptions.TimeoutError() from exc
# asyncio.exceptions.TimeoutError
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/distributed/worker.py", line 3296, in gather_dep
#     response = await get_data_from_worker(
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/distributed/worker.py", line 4680, in get_data_from_worker
#     return await retry_operation(_get_data, operation="get_data_from_worker")
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/distributed/utils_comm.py", line 381, in retry_operation
#     return await retry(
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/distributed/utils_comm.py", line 366, in retry
#     return await coro()
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/distributed/worker.py", line 4657, in _get_data
#     comm = await rpc.connect(worker)
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/distributed/core.py", line 1202, in connect
#     return await connect_attempt
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/distributed/core.py", line 1138, in _connect
#     comm = await connect(
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/distributed/comm/core.py", line 331, in connect
#     raise OSError(
# OSError: Timed out during handshake while connecting to tcp://127.0.0.1:59820 after 30 s
# 2022-06-17 15:06:35,970 - distributed.worker - ERROR - Worker stream died during communication: tcp://127.0.0.1:59817
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/distributed/comm/tcp.py", line 266, in write
#     async def write(self, msg, serializers=None, on_error="message"):
# asyncio.exceptions.CancelledError
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/asyncio/tasks.py", line 418, in wait_for
#     return fut.result()
# asyncio.exceptions.CancelledError
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/distributed/comm/core.py", line 327, in connect
#     await asyncio.wait_for(comm.write(local_info), time_left())
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/asyncio/tasks.py", line 420, in wait_for
#     raise exceptions.TimeoutError() from exc
# asyncio.exceptions.TimeoutError
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/distributed/worker.py", line 3296, in gather_dep
#     response = await get_data_from_worker(
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/distributed/worker.py", line 4680, in get_data_from_worker
#     return await retry_operation(_get_data, operation="get_data_from_worker")
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/distributed/utils_comm.py", line 381, in retry_operation
#     return await retry(
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/distributed/utils_comm.py", line 366, in retry
#     return await coro()
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/distributed/worker.py", line 4657, in _get_data
#     comm = await rpc.connect(worker)
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/distributed/core.py", line 1202, in connect
#     return await connect_attempt
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/distributed/core.py", line 1138, in _connect
#     comm = await connect(
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/distributed/comm/core.py", line 331, in connect
#     raise OSError(
# OSError: Timed out during handshake while connecting to tcp://127.0.0.1:59817 after 30 s
# 2022-06-17 15:07:08,882 - distributed.worker - ERROR - Worker stream died during communication: tcp://127.0.0.1:59820
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/distributed/comm/tcp.py", line 217, in read
#     async def read(self, deserializers=None):
# asyncio.exceptions.CancelledError
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/asyncio/tasks.py", line 418, in wait_for
#     return fut.result()
# asyncio.exceptions.CancelledError
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/distributed/comm/core.py", line 326, in connect
#     handshake = await asyncio.wait_for(comm.read(), time_left())
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/asyncio/tasks.py", line 420, in wait_for
#     raise exceptions.TimeoutError() from exc
# asyncio.exceptions.TimeoutError
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/distributed/worker.py", line 3296, in gather_dep
#     response = await get_data_from_worker(
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/distributed/worker.py", line 4680, in get_data_from_worker
#     return await retry_operation(_get_data, operation="get_data_from_worker")
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/distributed/utils_comm.py", line 381, in retry_operation
#     return await retry(
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/distributed/utils_comm.py", line 366, in retry
#     return await coro()
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/distributed/worker.py", line 4657, in _get_data
#     comm = await rpc.connect(worker)
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/distributed/core.py", line 1202, in connect
#     return await connect_attempt
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/distributed/core.py", line 1138, in _connect
#     comm = await connect(
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/distributed/comm/core.py", line 331, in connect
#     raise OSError(
# OSError: Timed out during handshake while connecting to tcp://127.0.0.1:59820 after 30 s

# %% [markdown]
# The newly generated parquet files are read into a dataframe.

# %%
df=dd.read_parquet("parquet")

# %% [markdown]
# Let's look into the amount of cases we have:

# %%
len(df)
# Out:
# 7972537

# %% [markdown]
# This time the missing values got handled pretty well and the dataframe has a structure we can work with

# %%
df.head(5)
# Out:
#                                user_name user_screen_name language  \
# tweet_id
# 1511650360317861894         Jaineet King      JaineetKing       en
# 1511650360385052680  Mohd Nazri Mohd Nor  MohdNazriMohdN9       en
# 1511650360414584836     Borsalino Kizaru     kborsalino00       en
# 1511650360628293635              jhangvi  Alikhan13319125       en
# 1511650360758263811          Imola_red ?     Imola_red888       en
#
#                      nb_retweets  nb_likes              user_id provider  \
# tweet_id
# 1511650360317861894            0         0  1510316194418597897   random
# 1511650360385052680            0         0  1452885627595149312   random
# 1511650360414584836            0         0  1487770961176719367   random
# 1511650360628293635            0         0  1507030320847245312   random
# 1511650360758263811            0         0  1171555019478507520   random
#
#                      isSensitive  countStatus  \
# tweet_id
# 1511650360317861894        False            8
# 1511650360385052680        False            1
# 1511650360414584836        False            3
# 1511650360628293635        False            2
# 1511650360758263811        False            4
#
#                                                                   text  \
# tweet_id
# 1511650360317861894  @purpleNFTmuseum TALKADO NFT #Whitelist IS LIV...
# 1511650360385052680  RT @AmeerGiveaway: Hey guys it’s Ameer! Just m...
# 1511650360414584836  @yogetoth Hello ELEFbody\n\nStarting April 8, ...
# 1511650360628293635  @LaCryptoMonnai1 6/4\n?????? ??????\n ?REAL UT...
# 1511650360758263811  RT @LOcommunityNFT: Fatima living that Lo-Fi l...
#
#                                       user_location    keyword  isRetweeted  \
# tweet_id
# 1511650360317861894                            None  top_banks        False
# 1511650360385052680  Kuala Lumpur City, Kuala Lumpu  top_banks        False
# 1511650360414584836                            None  top_banks        False
# 1511650360628293635                            None  top_banks        False
# 1511650360758263811             Birmingham, England  top_banks        False
#
#                        report_date  isRetweet
# tweet_id
# 1511650360317861894  1649240505000      False
# 1511650360385052680  1649240505000       True
# 1511650360414584836  1649240505000      False
# 1511650360628293635  1649240505000      False
# 1511650360758263811  1649240505000       True

# %% [markdown]
# Dropping unwanted columns:

# %%
df_clean = df.drop(columns = ['user_name','provider', 'isSensitive','user_location','keyword','isRetweeted','isRetweet'])
df_clean.head()
# Out:
#                     user_screen_name language  nb_retweets  nb_likes  \
# tweet_id
# 1511650360317861894      JaineetKing       en            0         0
# 1511650360385052680  MohdNazriMohdN9       en            0         0
# 1511650360414584836     kborsalino00       en            0         0
# 1511650360628293635  Alikhan13319125       en            0         0
# 1511650360758263811     Imola_red888       en            0         0
#
#                                  user_id  countStatus  \
# tweet_id
# 1511650360317861894  1510316194418597897            8
# 1511650360385052680  1452885627595149312            1
# 1511650360414584836  1487770961176719367            3
# 1511650360628293635  1507030320847245312            2
# 1511650360758263811  1171555019478507520            4
#
#                                                                   text  \
# tweet_id
# 1511650360317861894  @purpleNFTmuseum TALKADO NFT #Whitelist IS LIV...
# 1511650360385052680  RT @AmeerGiveaway: Hey guys it’s Ameer! Just m...
# 1511650360414584836  @yogetoth Hello ELEFbody\n\nStarting April 8, ...
# 1511650360628293635  @LaCryptoMonnai1 6/4\n?????? ??????\n ?REAL UT...
# 1511650360758263811  RT @LOcommunityNFT: Fatima living that Lo-Fi l...
#
#                        report_date
# tweet_id
# 1511650360317861894  1649240505000
# 1511650360385052680  1649240505000
# 1511650360414584836  1649240505000
# 1511650360628293635  1649240505000
# 1511650360758263811  1649240505000

# %% [markdown]
# Deleting all rows with text not in English:

# %%
df_clean = df_clean[df_clean.language == 'en']
df_clean = df_clean.drop(columns = ['language', 'report_date'])
df_clean.head(10)
# Out:
#                     user_screen_name  nb_retweets  nb_likes  \
# tweet_id
# 1511650360317861894      JaineetKing            0         0
# 1511650360385052680  MohdNazriMohdN9            0         0
# 1511650360414584836     kborsalino00            0         0
# 1511650360628293635  Alikhan13319125            0         0
# 1511650360758263811     Imola_red888            0         0
# 1511650360833716230          Mrszoe8            0         0
# 1511650360905113600          ngorji3            0         0
# 1511650360951255040       manishms75            0         0
# 1511650361211506688   Aprilw1nberkah            0         0
# 1511650361249079297        Spice378j            0         0
#
#                                  user_id  countStatus  \
# tweet_id
# 1511650360317861894  1510316194418597897            8
# 1511650360385052680  1452885627595149312            1
# 1511650360414584836  1487770961176719367            3
# 1511650360628293635  1507030320847245312            2
# 1511650360758263811  1171555019478507520            4
# 1511650360833716230  1497442153592606722            7
# 1511650360905113600  1486787670491766784            6
# 1511650360951255040  1467093830830800902            5
# 1511650361211506688  1499998570899914753           10
# 1511650361249079297  1260085132855312384            9
#
#                                                                   text
# tweet_id
# 1511650360317861894  @purpleNFTmuseum TALKADO NFT #Whitelist IS LIV...
# 1511650360385052680  RT @AmeerGiveaway: Hey guys it’s Ameer! Just m...
# 1511650360414584836  @yogetoth Hello ELEFbody\n\nStarting April 8, ...
# 1511650360628293635  @LaCryptoMonnai1 6/4\n?????? ??????\n ?REAL UT...
# 1511650360758263811  RT @LOcommunityNFT: Fatima living that Lo-Fi l...
# 1511650360833716230              PROMOTE IT ON https://t.co/0kaEzKyesI
# 1511650360905113600  RT @bigtraderrrrr: @AltcoinWorldcom New genera...
# 1511650360951255040  RT @Hujemi2: @autofarmnetwork A great project ...
# 1511650361211506688  RT @TiarCrypto: $250 | 3,5 JUTA in 72 HOURS\n\...
# 1511650361249079297  RT @Play_Ukiyo: ?? Ukiyo X PXN ?\n\nWe have te...

# %% [markdown]
# Dropping more unwanted columns:

# %%
df_clean = df_clean.drop(columns = ['nb_retweets', 'nb_likes'])
df_clean.head(10)
# Out:
#                     user_screen_name              user_id  countStatus  \
# tweet_id
# 1511650360317861894      JaineetKing  1510316194418597897            8
# 1511650360385052680  MohdNazriMohdN9  1452885627595149312            1
# 1511650360414584836     kborsalino00  1487770961176719367            3
# 1511650360628293635  Alikhan13319125  1507030320847245312            2
# 1511650360758263811     Imola_red888  1171555019478507520            4
# 1511650360833716230          Mrszoe8  1497442153592606722            7
# 1511650360905113600          ngorji3  1486787670491766784            6
# 1511650360951255040       manishms75  1467093830830800902            5
# 1511650361211506688   Aprilw1nberkah  1499998570899914753           10
# 1511650361249079297        Spice378j  1260085132855312384            9
#
#                                                                   text
# tweet_id
# 1511650360317861894  @purpleNFTmuseum TALKADO NFT #Whitelist IS LIV...
# 1511650360385052680  RT @AmeerGiveaway: Hey guys it’s Ameer! Just m...
# 1511650360414584836  @yogetoth Hello ELEFbody\n\nStarting April 8, ...
# 1511650360628293635  @LaCryptoMonnai1 6/4\n?????? ??????\n ?REAL UT...
# 1511650360758263811  RT @LOcommunityNFT: Fatima living that Lo-Fi l...
# 1511650360833716230              PROMOTE IT ON https://t.co/0kaEzKyesI
# 1511650360905113600  RT @bigtraderrrrr: @AltcoinWorldcom New genera...
# 1511650360951255040  RT @Hujemi2: @autofarmnetwork A great project ...
# 1511650361211506688  RT @TiarCrypto: $250 | 3,5 JUTA in 72 HOURS\n\...
# 1511650361249079297  RT @Play_Ukiyo: ?? Ukiyo X PXN ?\n\nWe have te...

# %% [markdown]
# Here, we want to save the data frame so that we can work with it later without going through all the previous steps every time. We are saving it as a parquet file.

# %%
df_clean.to_parquet('/Users/romanpavlyutin/Desktop/df.parquet.gzip', compression='gzip')

# %%
df2 = dd.read_parquet('/Users/romanpavlyutin/Desktop/df.parquet.gzip')
df2.head(15)
# Out:
#                     user_screen_name              user_id  countStatus  \
# tweet_id
# 1511650360317861894      JaineetKing  1510316194418597897            8
# 1511650360385052680  MohdNazriMohdN9  1452885627595149312            1
# 1511650360414584836     kborsalino00  1487770961176719367            3
# 1511650360628293635  Alikhan13319125  1507030320847245312            2
# 1511650360758263811     Imola_red888  1171555019478507520            4
# 1511650360833716230          Mrszoe8  1497442153592606722            7
# 1511650360905113600          ngorji3  1486787670491766784            6
# 1511650360951255040       manishms75  1467093830830800902            5
# 1511650361211506688   Aprilw1nberkah  1499998570899914753           10
# 1511650361249079297        Spice378j  1260085132855312384            9
# 1511650361341530118       DeJudyline  1213410934930034689           14
# 1511650361349705731     Alex_Arnault           2801770498           19
# 1511650361366491136      phlegmmmmmm  1349066783009943559           11
# 1511650361445998595          CRYPT_L   803184977877663744           12
# 1511650361488027653           aisynx  1341292004991385604           16
#
#                                                                   text
# tweet_id
# 1511650360317861894  @purpleNFTmuseum TALKADO NFT #Whitelist IS LIV...
# 1511650360385052680  RT @AmeerGiveaway: Hey guys it’s Ameer! Just m...
# 1511650360414584836  @yogetoth Hello ELEFbody\n\nStarting April 8, ...
# 1511650360628293635  @LaCryptoMonnai1 6/4\n?????? ??????\n ?REAL UT...
# 1511650360758263811  RT @LOcommunityNFT: Fatima living that Lo-Fi l...
# 1511650360833716230              PROMOTE IT ON https://t.co/0kaEzKyesI
# 1511650360905113600  RT @bigtraderrrrr: @AltcoinWorldcom New genera...
# 1511650360951255040  RT @Hujemi2: @autofarmnetwork A great project ...
# 1511650361211506688  RT @TiarCrypto: $250 | 3,5 JUTA in 72 HOURS\n\...
# 1511650361249079297  RT @Play_Ukiyo: ?? Ukiyo X PXN ?\n\nWe have te...
# 1511650361341530118  RT @smallcappick: @wearecultdao     ?\n#wearec...
# 1511650361349705731  will the Treasury give clarity tomorrow? #XRP ...
# 1511650361366491136  RT @Texan_Shinja: Listen to SHINJA Rock Radio ...
# 1511650361445998595  RT @CryptoGemsCom: Show me an #Crypto project ...
# 1511650361488027653  RT @VioletEmoji_NFT: ?#GIVEAWAY?\n\nPrizes: \n...

# %% [markdown]
# We have split this project into several notebooks, so that it doesn't get too messy and it is easier to keep track of things, and so that we do not have to go through all the steps everytime.
